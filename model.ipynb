# %%
#!/usr/bin/env python
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# %pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pylint in /home/vscode/.local/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (2.15.3)
# Requirement already satisfied: pytest in /home/vscode/.local/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (7.1.3)
# Requirement already satisfied: black in /home/vscode/.local/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (22.8.0)
# Requirement already satisfied: click in /home/vscode/.local/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (8.1.3)
# Requirement already satisfied: streamlit in /home/vscode/.local/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (1.13.0)
# Requirement already satisfied: gradio in /home/vscode/.local/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (3.4.1)
# Requirement already satisfied: ipython in /home/vscode/.local/lib/python3.10/site-packages (from -r requirements.txt (line 8)) (8.5.0)
# Requirement already satisfied: boto3==1.24.87 in /home/vscode/.local/lib/python3.10/site-packages (from -r requirements.txt (line 9)) (1.24.87)
# Requirement already satisfied: jupyter==1.0.0 in /home/vscode/.local/lib/python3.10/site-packages (from -r requirements.txt (line 11)) (1.0.0)
# Requirement already satisfied: pandas==1.5.0 in /home/vscode/.local/lib/python3.10/site-packages (from -r requirements.txt (line 12)) (1.5.0)
# Requirement already satisfied: numpy==1.23.3 in /home/vscode/.local/lib/python3.10/site-packages (from -r requirements.txt (line 13)) (1.23.3)
# Requirement already satisfied: scikit-learn==1.1.2 in /home/vscode/.local/lib/python3.10/site-packages (from -r requirements.txt (line 14)) (1.1.2)
# Requirement already satisfied: matplotlib==3.6.0 in /home/vscode/.local/lib/python3.10/site-packages (from -r requirements.txt (line 15)) (3.6.0)
# Requirement already satisfied: seaborn==0.12.0 in /home/vscode/.local/lib/python3.10/site-packages (from -r requirements.txt (line 16)) (0.12.0)
# Requirement already satisfied: dask==2022.9.2 in /home/vscode/.local/lib/python3.10/site-packages (from -r requirements.txt (line 17)) (2022.9.2)
# Requirement already satisfied: config in /home/vscode/.local/lib/python3.10/site-packages (from -r requirements.txt (line 18)) (0.5.1)
# Requirement already satisfied: geopy==2.2.0 in /home/vscode/.local/lib/python3.10/site-packages (from -r requirements.txt (line 20)) (2.2.0)
# Requirement already satisfied: protobuf==3.16.0 in /home/vscode/.local/lib/python3.10/site-packages (from -r requirements.txt (line 24)) (3.16.0)
# Requirement already satisfied: onnx==1.12.0 in /home/vscode/.local/lib/python3.10/site-packages (from -r requirements.txt (line 25)) (1.12.0)
# Requirement already satisfied: mlflow==1.29.0 in /home/vscode/.local/lib/python3.10/site-packages (from -r requirements.txt (line 26)) (1.29.0)
# Requirement already satisfied: databricks==0.2 in /home/vscode/.local/lib/python3.10/site-packages (from -r requirements.txt (line 27)) (0.2)
# Requirement already satisfied: databricks-cli==0.17.3 in /home/vscode/.local/lib/python3.10/site-packages (from -r requirements.txt (line 28)) (0.17.3)
# Requirement already satisfied: databricks-sql-connector==2.1.0 in /home/vscode/.local/lib/python3.10/site-packages (from -r requirements.txt (line 29)) (2.1.0)
# Requirement already satisfied: transformers==4.22.2 in /home/vscode/.local/lib/python3.10/site-packages (from -r requirements.txt (line 31)) (4.22.2)
# Requirement already satisfied: datasets==2.5.2 in /home/vscode/.local/lib/python3.10/site-packages (from -r requirements.txt (line 32)) (2.5.2)
# Requirement already satisfied: tokenizers==0.12.1 in /home/vscode/.local/lib/python3.10/site-packages (from -r requirements.txt (line 33)) (0.12.1)
# Requirement already satisfied: torch==1.12.1 in /home/vscode/.local/lib/python3.10/site-packages (from -r requirements.txt (line 35)) (1.12.1)
# Requirement already satisfied: torchvision==0.13.1 in /home/vscode/.local/lib/python3.10/site-packages (from -r requirements.txt (line 36)) (0.13.1)
# Requirement already satisfied: tensorflow==2.10.0 in /home/vscode/.local/lib/python3.10/site-packages (from -r requirements.txt (line 37)) (2.10.0)
# Requirement already satisfied: sagemaker>=2.48.0 in /home/vscode/.local/lib/python3.10/site-packages (from -r requirements.txt (line 39)) (2.112.0)
# Requirement already satisfied: tzlocal>=1.1 in /home/vscode/.local/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 6)) (4.2)
# Requirement already satisfied: blinker>=1.0.0 in /home/vscode/.local/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 6)) (1.5)
# Requirement already satisfied: python-dateutil in /home/vscode/.local/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 6)) (2.8.2)
# Requirement already satisfied: requests>=2.4 in /home/vscode/.local/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 6)) (2.28.1)
# Requirement already satisfied: rich>=10.11.0 in /home/vscode/.local/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 6)) (12.6.0)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /home/vscode/.local/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 6)) (4.3.0)
# Requirement already satisfied: packaging>=14.1 in /home/vscode/.local/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 6)) (21.3)
# Requirement already satisfied: pyarrow>=4.0 in /home/vscode/.local/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 6)) (9.0.0)
# Requirement already satisfied: tornado>=5.0 in /home/vscode/.local/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 6)) (6.2)
# Requirement already satisfied: pillow>=6.2.0 in /home/vscode/.local/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 6)) (9.2.0)
# Requirement already satisfied: altair>=3.2.0 in /home/vscode/.local/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 6)) (4.2.0)
# Requirement already satisfied: validators>=0.2 in /home/vscode/.local/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 6)) (0.20.0)
# Requirement already satisfied: toml in /home/vscode/.local/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 6)) (0.10.2)
# Requirement already satisfied: semver in /home/vscode/.local/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 6)) (2.13.0)
# Requirement already satisfied: importlib-metadata>=1.4 in /home/vscode/.local/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 6)) (4.13.0)
# Requirement already satisfied: gitpython!=3.1.19 in /home/vscode/.local/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 6)) (3.1.27)
# Requirement already satisfied: cachetools>=4.0 in /home/vscode/.local/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 6)) (5.2.0)
# Requirement already satisfied: pympler>=0.9 in /home/vscode/.local/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 6)) (1.0.1)
# Requirement already satisfied: watchdog in /home/vscode/.local/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 6)) (2.1.9)
# Requirement already satisfied: pydeck>=0.1.dev5 in /home/vscode/.local/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 6)) (0.8.0b3)
# Requirement already satisfied: fastapi in /home/vscode/.local/lib/python3.10/site-packages (from gradio->-r requirements.txt (line 7)) (0.85.0)
# Requirement already satisfied: websockets in /home/vscode/.local/lib/python3.10/site-packages (from gradio->-r requirements.txt (line 7)) (10.3)
# Requirement already satisfied: pyyaml in /home/vscode/.local/lib/python3.10/site-packages (from gradio->-r requirements.txt (line 7)) (6.0)
# Requirement already satisfied: orjson in /home/vscode/.local/lib/python3.10/site-packages (from gradio->-r requirements.txt (line 7)) (3.8.0)
# Requirement already satisfied: ffmpy in /home/vscode/.local/lib/python3.10/site-packages (from gradio->-r requirements.txt (line 7)) (0.3.0)
# Requirement already satisfied: markdown-it-py[linkify,plugins] in /home/vscode/.local/lib/python3.10/site-packages (from gradio->-r requirements.txt (line 7)) (2.1.0)
# Requirement already satisfied: pydantic in /home/vscode/.local/lib/python3.10/site-packages (from gradio->-r requirements.txt (line 7)) (1.10.2)
# Requirement already satisfied: paramiko in /home/vscode/.local/lib/python3.10/site-packages (from gradio->-r requirements.txt (line 7)) (2.11.0)
# Requirement already satisfied: h11<0.13,>=0.11 in /home/vscode/.local/lib/python3.10/site-packages (from gradio->-r requirements.txt (line 7)) (0.12.0)
# Requirement already satisfied: aiohttp in /home/vscode/.local/lib/python3.10/site-packages (from gradio->-r requirements.txt (line 7)) (3.8.3)
# Requirement already satisfied: jinja2 in /home/vscode/.local/lib/python3.10/site-packages (from gradio->-r requirements.txt (line 7)) (3.1.2)
# Requirement already satisfied: pydub in /home/vscode/.local/lib/python3.10/site-packages (from gradio->-r requirements.txt (line 7)) (0.25.1)
# Requirement already satisfied: fsspec in /home/vscode/.local/lib/python3.10/site-packages (from gradio->-r requirements.txt (line 7)) (2022.8.2)
# Requirement already satisfied: python-multipart in /home/vscode/.local/lib/python3.10/site-packages (from gradio->-r requirements.txt (line 7)) (0.0.5)
# Requirement already satisfied: uvicorn in /home/vscode/.local/lib/python3.10/site-packages (from gradio->-r requirements.txt (line 7)) (0.18.3)
# Requirement already satisfied: pycryptodome in /home/vscode/.local/lib/python3.10/site-packages (from gradio->-r requirements.txt (line 7)) (3.15.0)
# Requirement already satisfied: httpx in /home/vscode/.local/lib/python3.10/site-packages (from gradio->-r requirements.txt (line 7)) (0.23.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/vscode/.local/lib/python3.10/site-packages (from boto3==1.24.87->-r requirements.txt (line 9)) (1.0.1)
# Requirement already satisfied: botocore<1.28.0,>=1.27.87 in /home/vscode/.local/lib/python3.10/site-packages (from boto3==1.24.87->-r requirements.txt (line 9)) (1.27.89)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /home/vscode/.local/lib/python3.10/site-packages (from boto3==1.24.87->-r requirements.txt (line 9)) (0.6.0)
# Requirement already satisfied: notebook in /home/vscode/.local/lib/python3.10/site-packages (from jupyter==1.0.0->-r requirements.txt (line 11)) (6.4.12)
# Requirement already satisfied: jupyter-console in /home/vscode/.local/lib/python3.10/site-packages (from jupyter==1.0.0->-r requirements.txt (line 11)) (6.4.4)
# Requirement already satisfied: ipykernel in /home/vscode/.local/lib/python3.10/site-packages (from jupyter==1.0.0->-r requirements.txt (line 11)) (6.16.0)
# Requirement already satisfied: ipywidgets in /home/vscode/.local/lib/python3.10/site-packages (from jupyter==1.0.0->-r requirements.txt (line 11)) (8.0.2)
# Requirement already satisfied: qtconsole in /home/vscode/.local/lib/python3.10/site-packages (from jupyter==1.0.0->-r requirements.txt (line 11)) (5.3.2)
# Requirement already satisfied: nbconvert in /home/vscode/.local/lib/python3.10/site-packages (from jupyter==1.0.0->-r requirements.txt (line 11)) (7.1.0)
# Requirement already satisfied: pytz>=2020.1 in /home/vscode/.local/lib/python3.10/site-packages (from pandas==1.5.0->-r requirements.txt (line 12)) (2022.4)
# Requirement already satisfied: scipy>=1.3.2 in /home/vscode/.local/lib/python3.10/site-packages (from scikit-learn==1.1.2->-r requirements.txt (line 14)) (1.9.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/vscode/.local/lib/python3.10/site-packages (from scikit-learn==1.1.2->-r requirements.txt (line 14)) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in /home/vscode/.local/lib/python3.10/site-packages (from scikit-learn==1.1.2->-r requirements.txt (line 14)) (1.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/vscode/.local/lib/python3.10/site-packages (from matplotlib==3.6.0->-r requirements.txt (line 15)) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /home/vscode/.local/lib/python3.10/site-packages (from matplotlib==3.6.0->-r requirements.txt (line 15)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/vscode/.local/lib/python3.10/site-packages (from matplotlib==3.6.0->-r requirements.txt (line 15)) (4.37.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/vscode/.local/lib/python3.10/site-packages (from matplotlib==3.6.0->-r requirements.txt (line 15)) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /home/vscode/.local/lib/python3.10/site-packages (from matplotlib==3.6.0->-r requirements.txt (line 15)) (1.0.5)
# Requirement already satisfied: toolz>=0.8.2 in /home/vscode/.local/lib/python3.10/site-packages (from dask==2022.9.2->-r requirements.txt (line 17)) (0.12.0)
# Requirement already satisfied: cloudpickle>=1.1.1 in /home/vscode/.local/lib/python3.10/site-packages (from dask==2022.9.2->-r requirements.txt (line 17)) (2.2.0)
# Requirement already satisfied: partd>=0.3.10 in /home/vscode/.local/lib/python3.10/site-packages (from dask==2022.9.2->-r requirements.txt (line 17)) (1.3.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /home/vscode/.local/lib/python3.10/site-packages (from geopy==2.2.0->-r requirements.txt (line 20)) (1.52)
# Requirement already satisfied: six>=1.9 in /home/vscode/.local/lib/python3.10/site-packages (from protobuf==3.16.0->-r requirements.txt (line 24)) (1.16.0)
# Requirement already satisfied: gunicorn<21 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow==1.29.0->-r requirements.txt (line 26)) (20.1.0)
# Requirement already satisfied: docker<7,>=4.0.0 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow==1.29.0->-r requirements.txt (line 26)) (6.0.0)
# Requirement already satisfied: Flask<3 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow==1.29.0->-r requirements.txt (line 26)) (2.2.2)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow==1.29.0->-r requirements.txt (line 26)) (0.4.3)
# Requirement already satisfied: entrypoints<1 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow==1.29.0->-r requirements.txt (line 26)) (0.4)
# Requirement already satisfied: sqlalchemy<2,>=1.4.0 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow==1.29.0->-r requirements.txt (line 26)) (1.4.41)
# Requirement already satisfied: querystring-parser<2 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow==1.29.0->-r requirements.txt (line 26)) (1.2.4)
# Requirement already satisfied: prometheus-flask-exporter<1 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow==1.29.0->-r requirements.txt (line 26)) (0.20.3)
# Requirement already satisfied: alembic<2 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow==1.29.0->-r requirements.txt (line 26)) (1.8.1)
# Requirement already satisfied: pyjwt>=1.7.0 in /home/vscode/.local/lib/python3.10/site-packages (from databricks-cli==0.17.3->-r requirements.txt (line 28)) (2.5.0)
# Requirement already satisfied: tabulate>=0.7.7 in /home/vscode/.local/lib/python3.10/site-packages (from databricks-cli==0.17.3->-r requirements.txt (line 28)) (0.9.0)
# Requirement already satisfied: oauthlib>=3.1.0 in /home/vscode/.local/lib/python3.10/site-packages (from databricks-cli==0.17.3->-r requirements.txt (line 28)) (3.2.1)
# Requirement already satisfied: thrift<0.14.0,>=0.13.0 in /home/vscode/.local/lib/python3.10/site-packages (from databricks-sql-connector==2.1.0->-r requirements.txt (line 29)) (0.13.0)
# Requirement already satisfied: tqdm>=4.27 in /home/vscode/.local/lib/python3.10/site-packages (from transformers==4.22.2->-r requirements.txt (line 31)) (4.64.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/vscode/.local/lib/python3.10/site-packages (from transformers==4.22.2->-r requirements.txt (line 31)) (2022.9.13)
# Requirement already satisfied: filelock in /home/vscode/.local/lib/python3.10/site-packages (from transformers==4.22.2->-r requirements.txt (line 31)) (3.8.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.9.0 in /home/vscode/.local/lib/python3.10/site-packages (from transformers==4.22.2->-r requirements.txt (line 31)) (0.10.0)
# Requirement already satisfied: responses<0.19 in /home/vscode/.local/lib/python3.10/site-packages (from datasets==2.5.2->-r requirements.txt (line 32)) (0.18.0)
# Requirement already satisfied: dill<0.3.6 in /home/vscode/.local/lib/python3.10/site-packages (from datasets==2.5.2->-r requirements.txt (line 32)) (0.3.5.1)
# Requirement already satisfied: xxhash in /home/vscode/.local/lib/python3.10/site-packages (from datasets==2.5.2->-r requirements.txt (line 32)) (3.0.0)
# Requirement already satisfied: multiprocess in /home/vscode/.local/lib/python3.10/site-packages (from datasets==2.5.2->-r requirements.txt (line 32)) (0.70.13)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/vscode/.local/lib/python3.10/site-packages (from tensorflow==2.10.0->-r requirements.txt (line 37)) (3.3.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/vscode/.local/lib/python3.10/site-packages (from tensorflow==2.10.0->-r requirements.txt (line 37)) (1.49.1)
# Requirement already satisfied: termcolor>=1.1.0 in /home/vscode/.local/lib/python3.10/site-packages (from tensorflow==2.10.0->-r requirements.txt (line 37)) (2.0.1)
# Requirement already satisfied: wrapt>=1.11.0 in /home/vscode/.local/lib/python3.10/site-packages (from tensorflow==2.10.0->-r requirements.txt (line 37)) (1.14.1)
# Requirement already satisfied: h5py>=2.9.0 in /home/vscode/.local/lib/python3.10/site-packages (from tensorflow==2.10.0->-r requirements.txt (line 37)) (3.7.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/vscode/.local/lib/python3.10/site-packages (from tensorflow==2.10.0->-r requirements.txt (line 37)) (1.2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/vscode/.local/lib/python3.10/site-packages (from tensorflow==2.10.0->-r requirements.txt (line 37)) (0.27.0)
# Requirement already satisfied: keras<2.11,>=2.10.0 in /home/vscode/.local/lib/python3.10/site-packages (from tensorflow==2.10.0->-r requirements.txt (line 37)) (2.10.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /home/vscode/.local/lib/python3.10/site-packages (from tensorflow==2.10.0->-r requirements.txt (line 37)) (0.4.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /home/vscode/.local/lib/python3.10/site-packages (from tensorflow==2.10.0->-r requirements.txt (line 37)) (1.1.2)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in /home/vscode/.local/lib/python3.10/site-packages (from tensorflow==2.10.0->-r requirements.txt (line 37)) (2.10.0)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in /home/vscode/.local/lib/python3.10/site-packages (from tensorflow==2.10.0->-r requirements.txt (line 37)) (2.10.1)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/vscode/.local/lib/python3.10/site-packages (from tensorflow==2.10.0->-r requirements.txt (line 37)) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/vscode/.local/lib/python3.10/site-packages (from tensorflow==2.10.0->-r requirements.txt (line 37)) (14.0.6)
# Requirement already satisfied: flatbuffers>=2.0 in /home/vscode/.local/lib/python3.10/site-packages (from tensorflow==2.10.0->-r requirements.txt (line 37)) (22.9.24)
# Requirement already satisfied: astunparse>=1.6.0 in /home/vscode/.local/lib/python3.10/site-packages (from tensorflow==2.10.0->-r requirements.txt (line 37)) (1.6.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/site-packages (from tensorflow==2.10.0->-r requirements.txt (line 37)) (63.2.0)
# Requirement already satisfied: isort<6,>=4.2.5 in /home/vscode/.local/lib/python3.10/site-packages (from pylint->-r requirements.txt (line 2)) (5.10.1)
# Requirement already satisfied: tomlkit>=0.10.1 in /home/vscode/.local/lib/python3.10/site-packages (from pylint->-r requirements.txt (line 2)) (0.11.5)
# Requirement already satisfied: astroid<=2.14.0-dev0,>=2.12.10 in /home/vscode/.local/lib/python3.10/site-packages (from pylint->-r requirements.txt (line 2)) (2.12.10)
# Requirement already satisfied: mccabe<0.8,>=0.6 in /home/vscode/.local/lib/python3.10/site-packages (from pylint->-r requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: tomli>=1.1.0 in /home/vscode/.local/lib/python3.10/site-packages (from pylint->-r requirements.txt (line 2)) (2.0.1)
# Requirement already satisfied: platformdirs>=2.2.0 in /home/vscode/.local/lib/python3.10/site-packages (from pylint->-r requirements.txt (line 2)) (2.5.2)
# Requirement already satisfied: py>=1.8.2 in /home/vscode/.local/lib/python3.10/site-packages (from pytest->-r requirements.txt (line 3)) (1.11.0)
# Requirement already satisfied: iniconfig in /home/vscode/.local/lib/python3.10/site-packages (from pytest->-r requirements.txt (line 3)) (1.1.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /home/vscode/.local/lib/python3.10/site-packages (from pytest->-r requirements.txt (line 3)) (1.0.0)
# Requirement already satisfied: attrs>=19.2.0 in /home/vscode/.local/lib/python3.10/site-packages (from pytest->-r requirements.txt (line 3)) (22.1.0)
# Requirement already satisfied: pathspec>=0.9.0 in /home/vscode/.local/lib/python3.10/site-packages (from black->-r requirements.txt (line 4)) (0.10.1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /home/vscode/.local/lib/python3.10/site-packages (from black->-r requirements.txt (line 4)) (0.4.3)
# Requirement already satisfied: traitlets>=5 in /home/vscode/.local/lib/python3.10/site-packages (from ipython->-r requirements.txt (line 8)) (5.4.0)
# Requirement already satisfied: stack-data in /home/vscode/.local/lib/python3.10/site-packages (from ipython->-r requirements.txt (line 8)) (0.5.1)
# Requirement already satisfied: pygments>=2.4.0 in /home/vscode/.local/lib/python3.10/site-packages (from ipython->-r requirements.txt (line 8)) (2.13.0)
# Requirement already satisfied: pexpect>4.3 in /home/vscode/.local/lib/python3.10/site-packages (from ipython->-r requirements.txt (line 8)) (4.8.0)
# Requirement already satisfied: pickleshare in /home/vscode/.local/lib/python3.10/site-packages (from ipython->-r requirements.txt (line 8)) (0.7.5)
# Requirement already satisfied: backcall in /home/vscode/.local/lib/python3.10/site-packages (from ipython->-r requirements.txt (line 8)) (0.2.0)
# Requirement already satisfied: decorator in /home/vscode/.local/lib/python3.10/site-packages (from ipython->-r requirements.txt (line 8)) (5.1.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in /home/vscode/.local/lib/python3.10/site-packages (from ipython->-r requirements.txt (line 8)) (3.0.31)
# Requirement already satisfied: matplotlib-inline in /home/vscode/.local/lib/python3.10/site-packages (from ipython->-r requirements.txt (line 8)) (0.1.6)
# Requirement already satisfied: jedi>=0.16 in /home/vscode/.local/lib/python3.10/site-packages (from ipython->-r requirements.txt (line 8)) (0.18.1)
# Requirement already satisfied: pathos in /home/vscode/.local/lib/python3.10/site-packages (from sagemaker>=2.48.0->-r requirements.txt (line 39)) (0.2.9)
# Requirement already satisfied: smdebug-rulesconfig==1.0.1 in /home/vscode/.local/lib/python3.10/site-packages (from sagemaker>=2.48.0->-r requirements.txt (line 39)) (1.0.1)
# Requirement already satisfied: schema in /home/vscode/.local/lib/python3.10/site-packages (from sagemaker>=2.48.0->-r requirements.txt (line 39)) (0.7.5)
# Requirement already satisfied: protobuf3-to-dict<1.0,>=0.1.5 in /home/vscode/.local/lib/python3.10/site-packages (from sagemaker>=2.48.0->-r requirements.txt (line 39)) (0.1.5)
# Requirement already satisfied: Mako in /home/vscode/.local/lib/python3.10/site-packages (from alembic<2->mlflow==1.29.0->-r requirements.txt (line 26)) (1.2.3)
# Requirement already satisfied: jsonschema>=3.0 in /home/vscode/.local/lib/python3.10/site-packages (from altair>=3.2.0->streamlit->-r requirements.txt (line 6)) (4.16.0)
# Requirement already satisfied: lazy-object-proxy>=1.4.0 in /home/vscode/.local/lib/python3.10/site-packages (from astroid<=2.14.0-dev0,>=2.12.10->pylint->-r requirements.txt (line 2)) (1.7.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow==2.10.0->-r requirements.txt (line 37)) (0.37.1)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/vscode/.local/lib/python3.10/site-packages (from botocore<1.28.0,>=1.27.87->boto3==1.24.87->-r requirements.txt (line 9)) (1.26.12)
# Requirement already satisfied: websocket-client>=0.32.0 in /home/vscode/.local/lib/python3.10/site-packages (from docker<7,>=4.0.0->mlflow==1.29.0->-r requirements.txt (line 26)) (1.4.1)
# Requirement already satisfied: itsdangerous>=2.0 in /home/vscode/.local/lib/python3.10/site-packages (from Flask<3->mlflow==1.29.0->-r requirements.txt (line 26)) (2.1.2)
# Requirement already satisfied: Werkzeug>=2.2.2 in /home/vscode/.local/lib/python3.10/site-packages (from Flask<3->mlflow==1.29.0->-r requirements.txt (line 26)) (2.2.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/vscode/.local/lib/python3.10/site-packages (from aiohttp->gradio->-r requirements.txt (line 7)) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/vscode/.local/lib/python3.10/site-packages (from aiohttp->gradio->-r requirements.txt (line 7)) (1.3.1)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /home/vscode/.local/lib/python3.10/site-packages (from aiohttp->gradio->-r requirements.txt (line 7)) (2.1.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/vscode/.local/lib/python3.10/site-packages (from aiohttp->gradio->-r requirements.txt (line 7)) (1.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/vscode/.local/lib/python3.10/site-packages (from aiohttp->gradio->-r requirements.txt (line 7)) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/vscode/.local/lib/python3.10/site-packages (from aiohttp->gradio->-r requirements.txt (line 7)) (4.0.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/vscode/.local/lib/python3.10/site-packages (from gitpython!=3.1.19->streamlit->-r requirements.txt (line 6)) (4.0.9)
# Requirement already satisfied: zipp>=0.5 in /home/vscode/.local/lib/python3.10/site-packages (from importlib-metadata>=1.4->streamlit->-r requirements.txt (line 6)) (3.8.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/vscode/.local/lib/python3.10/site-packages (from jedi>=0.16->ipython->-r requirements.txt (line 8)) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/vscode/.local/lib/python3.10/site-packages (from jinja2->gradio->-r requirements.txt (line 7)) (2.1.1)
# Requirement already satisfied: locket in /home/vscode/.local/lib/python3.10/site-packages (from partd>=0.3.10->dask==2022.9.2->-r requirements.txt (line 17)) (1.0.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/vscode/.local/lib/python3.10/site-packages (from pexpect>4.3->ipython->-r requirements.txt (line 8)) (0.7.0)
# Requirement already satisfied: prometheus-client in /home/vscode/.local/lib/python3.10/site-packages (from prometheus-flask-exporter<1->mlflow==1.29.0->-r requirements.txt (line 26)) (0.14.1)
# Requirement already satisfied: wcwidth in /home/vscode/.local/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython->-r requirements.txt (line 8)) (0.2.5)
# Requirement already satisfied: idna<4,>=2.5 in /home/vscode/.local/lib/python3.10/site-packages (from requests>=2.4->streamlit->-r requirements.txt (line 6)) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vscode/.local/lib/python3.10/site-packages (from requests>=2.4->streamlit->-r requirements.txt (line 6)) (2022.9.24)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /home/vscode/.local/lib/python3.10/site-packages (from rich>=10.11.0->streamlit->-r requirements.txt (line 6)) (0.9.1)
# Requirement already satisfied: greenlet!=0.4.17 in /home/vscode/.local/lib/python3.10/site-packages (from sqlalchemy<2,>=1.4.0->mlflow==1.29.0->-r requirements.txt (line 26)) (1.1.3)
# Requirement already satisfied: markdown>=2.6.8 in /home/vscode/.local/lib/python3.10/site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0->-r requirements.txt (line 37)) (3.4.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/vscode/.local/lib/python3.10/site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0->-r requirements.txt (line 37)) (2.12.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/vscode/.local/lib/python3.10/site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0->-r requirements.txt (line 37)) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/vscode/.local/lib/python3.10/site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0->-r requirements.txt (line 37)) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/vscode/.local/lib/python3.10/site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0->-r requirements.txt (line 37)) (1.8.1)
# Requirement already satisfied: pytz-deprecation-shim in /home/vscode/.local/lib/python3.10/site-packages (from tzlocal>=1.1->streamlit->-r requirements.txt (line 6)) (0.1.0.post0)
# Requirement already satisfied: starlette==0.20.4 in /home/vscode/.local/lib/python3.10/site-packages (from fastapi->gradio->-r requirements.txt (line 7)) (0.20.4)
# Requirement already satisfied: anyio<5,>=3.4.0 in /home/vscode/.local/lib/python3.10/site-packages (from starlette==0.20.4->fastapi->gradio->-r requirements.txt (line 7)) (3.6.1)
# Requirement already satisfied: sniffio in /home/vscode/.local/lib/python3.10/site-packages (from httpx->gradio->-r requirements.txt (line 7)) (1.3.0)
# Requirement already satisfied: httpcore<0.16.0,>=0.15.0 in /home/vscode/.local/lib/python3.10/site-packages (from httpx->gradio->-r requirements.txt (line 7)) (0.15.0)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in /home/vscode/.local/lib/python3.10/site-packages (from httpx->gradio->-r requirements.txt (line 7)) (1.5.0)
# Requirement already satisfied: debugpy>=1.0 in /home/vscode/.local/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->-r requirements.txt (line 11)) (1.6.3)
# Requirement already satisfied: nest-asyncio in /home/vscode/.local/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->-r requirements.txt (line 11)) (1.5.6)
# Requirement already satisfied: psutil in /home/vscode/.local/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->-r requirements.txt (line 11)) (5.9.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/vscode/.local/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->-r requirements.txt (line 11)) (7.3.5)
# Requirement already satisfied: pyzmq>=17 in /home/vscode/.local/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->-r requirements.txt (line 11)) (24.0.1)
# Requirement already satisfied: widgetsnbextension~=4.0 in /home/vscode/.local/lib/python3.10/site-packages (from ipywidgets->jupyter==1.0.0->-r requirements.txt (line 11)) (4.0.3)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /home/vscode/.local/lib/python3.10/site-packages (from ipywidgets->jupyter==1.0.0->-r requirements.txt (line 11)) (3.0.3)
# Requirement already satisfied: mdurl~=0.1 in /home/vscode/.local/lib/python3.10/site-packages (from markdown-it-py[linkify,plugins]->gradio->-r requirements.txt (line 7)) (0.1.2)
# Requirement already satisfied: linkify-it-py~=1.0 in /home/vscode/.local/lib/python3.10/site-packages (from markdown-it-py[linkify,plugins]->gradio->-r requirements.txt (line 7)) (1.0.3)
# Requirement already satisfied: mdit-py-plugins in /home/vscode/.local/lib/python3.10/site-packages (from markdown-it-py[linkify,plugins]->gradio->-r requirements.txt (line 7)) (0.3.1)
# Requirement already satisfied: beautifulsoup4 in /home/vscode/.local/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 11)) (4.11.1)
# Requirement already satisfied: bleach in /home/vscode/.local/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 11)) (5.0.1)
# Requirement already satisfied: jupyter-core>=4.7 in /home/vscode/.local/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 11)) (4.11.1)
# Requirement already satisfied: nbformat>=5.1 in /home/vscode/.local/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 11)) (5.6.1)
# Requirement already satisfied: mistune<3,>=2.0.3 in /home/vscode/.local/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 11)) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in /home/vscode/.local/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 11)) (0.6.8)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/vscode/.local/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 11)) (1.5.0)
# Requirement already satisfied: jupyterlab-pygments in /home/vscode/.local/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 11)) (0.2.2)
# Requirement already satisfied: tinycss2 in /home/vscode/.local/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 11)) (1.1.1)
# Requirement already satisfied: defusedxml in /home/vscode/.local/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 11)) (0.7.1)
# Requirement already satisfied: ipython-genutils in /home/vscode/.local/lib/python3.10/site-packages (from notebook->jupyter==1.0.0->-r requirements.txt (line 11)) (0.2.0)
# Requirement already satisfied: argon2-cffi in /home/vscode/.local/lib/python3.10/site-packages (from notebook->jupyter==1.0.0->-r requirements.txt (line 11)) (21.3.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/vscode/.local/lib/python3.10/site-packages (from notebook->jupyter==1.0.0->-r requirements.txt (line 11)) (0.16.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /home/vscode/.local/lib/python3.10/site-packages (from notebook->jupyter==1.0.0->-r requirements.txt (line 11)) (1.8.0)
# Requirement already satisfied: cryptography>=2.5 in /home/vscode/.local/lib/python3.10/site-packages (from paramiko->gradio->-r requirements.txt (line 7)) (38.0.1)
# Requirement already satisfied: bcrypt>=3.1.3 in /home/vscode/.local/lib/python3.10/site-packages (from paramiko->gradio->-r requirements.txt (line 7)) (4.0.0)
# Requirement already satisfied: pynacl>=1.0.1 in /home/vscode/.local/lib/python3.10/site-packages (from paramiko->gradio->-r requirements.txt (line 7)) (1.5.0)
# Requirement already satisfied: ppft>=1.7.6.5 in /home/vscode/.local/lib/python3.10/site-packages (from pathos->sagemaker>=2.48.0->-r requirements.txt (line 39)) (1.7.6.5)
# Requirement already satisfied: pox>=0.3.1 in /home/vscode/.local/lib/python3.10/site-packages (from pathos->sagemaker>=2.48.0->-r requirements.txt (line 39)) (0.3.1)
# Requirement already satisfied: qtpy>=2.0.1 in /home/vscode/.local/lib/python3.10/site-packages (from qtconsole->jupyter==1.0.0->-r requirements.txt (line 11)) (2.2.1)
# Requirement already satisfied: contextlib2>=0.5.5 in /home/vscode/.local/lib/python3.10/site-packages (from schema->sagemaker>=2.48.0->-r requirements.txt (line 39)) (21.6.0)
# Requirement already satisfied: pure-eval in /home/vscode/.local/lib/python3.10/site-packages (from stack-data->ipython->-r requirements.txt (line 8)) (0.2.2)
# Requirement already satisfied: executing in /home/vscode/.local/lib/python3.10/site-packages (from stack-data->ipython->-r requirements.txt (line 8)) (1.1.0)
# Requirement already satisfied: asttokens in /home/vscode/.local/lib/python3.10/site-packages (from stack-data->ipython->-r requirements.txt (line 8)) (2.0.8)
# Requirement already satisfied: cffi>=1.12 in /home/vscode/.local/lib/python3.10/site-packages (from cryptography>=2.5->paramiko->gradio->-r requirements.txt (line 7)) (1.15.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/vscode/.local/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit->-r requirements.txt (line 6)) (5.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/vscode/.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0->-r requirements.txt (line 37)) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/vscode/.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0->-r requirements.txt (line 37)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/vscode/.local/lib/python3.10/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow==2.10.0->-r requirements.txt (line 37)) (1.3.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/vscode/.local/lib/python3.10/site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit->-r requirements.txt (line 6)) (0.18.1)
# Requirement already satisfied: uc-micro-py in /home/vscode/.local/lib/python3.10/site-packages (from linkify-it-py~=1.0->markdown-it-py[linkify,plugins]->gradio->-r requirements.txt (line 7)) (1.0.1)
# Requirement already satisfied: fastjsonschema in /home/vscode/.local/lib/python3.10/site-packages (from nbformat>=5.1->nbconvert->jupyter==1.0.0->-r requirements.txt (line 11)) (2.16.2)
# Requirement already satisfied: argon2-cffi-bindings in /home/vscode/.local/lib/python3.10/site-packages (from argon2-cffi->notebook->jupyter==1.0.0->-r requirements.txt (line 11)) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /home/vscode/.local/lib/python3.10/site-packages (from beautifulsoup4->nbconvert->jupyter==1.0.0->-r requirements.txt (line 11)) (2.3.2.post1)
# Requirement already satisfied: webencodings in /home/vscode/.local/lib/python3.10/site-packages (from bleach->nbconvert->jupyter==1.0.0->-r requirements.txt (line 11)) (0.5.1)
# Requirement already satisfied: tzdata in /home/vscode/.local/lib/python3.10/site-packages (from pytz-deprecation-shim->tzlocal>=1.1->streamlit->-r requirements.txt (line 6)) (2022.4)
# Requirement already satisfied: pycparser in /home/vscode/.local/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=2.5->paramiko->gradio->-r requirements.txt (line 7)) (2.21)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/vscode/.local/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0->-r requirements.txt (line 37)) (0.4.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
from datasets import load_dataset, load_metric
from transformers import AutoTokenizer, DataCollatorWithPadding
from transformers import AutoModelForSequenceClassification
from transformers import TrainingArguments, Trainer
import numpy as np
# Out:
# 2022-10-10 01:03:20.186517: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-10 01:03:20.318770: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-10-10 01:03:20.318813: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-10-10 01:03:20.350307: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-10-10 01:03:21.138217: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2022-10-10 01:03:21.138352: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2022-10-10 01:03:21.138368: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
# load the dataset
dataset = load_dataset("yelp_review_full")

tokenizer = AutoTokenizer.from_pretrained("bert-base-cased")
# Out:
# Found cached dataset yelp_review_full (/home/vscode/.cache/huggingface/datasets/yelp_review_full/yelp_review_full/1.0.0/e8e18e19d7be9e75642fc66b198abadb116f73599ec89a69ba5dd8d1e57ba0bf)
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
# tokenizer helper function
def tokenize(batch):
    return tokenizer(batch['text'], padding='max_length', truncation=True)

# tokenize dataset
tokenized_datasets = dataset.map(tokenize, batched=True)

# can use if needed to reduce memory usage and training time
small_train_dataset = tokenized_datasets["train"].shuffle(seed=42).select(range(1000))
small_eval_dataset = tokenized_datasets["test"].shuffle(seed=42).select(range(1000))
# Out:
#   0%|          | 0/650 [00:00<?, ?ba/s]
# Loading cached processed dataset at /home/vscode/.cache/huggingface/datasets/yelp_review_full/yelp_review_full/1.0.0/e8e18e19d7be9e75642fc66b198abadb116f73599ec89a69ba5dd8d1e57ba0bf/cache-ac67ee3cdf34bb31.arrow
# Loading cached shuffled indices for dataset at /home/vscode/.cache/huggingface/datasets/yelp_review_full/yelp_review_full/1.0.0/e8e18e19d7be9e75642fc66b198abadb116f73599ec89a69ba5dd8d1e57ba0bf/cache-81f2e799941ed18f.arrow
# Loading cached shuffled indices for dataset at /home/vscode/.cache/huggingface/datasets/yelp_review_full/yelp_review_full/1.0.0/e8e18e19d7be9e75642fc66b198abadb116f73599ec89a69ba5dd8d1e57ba0bf/cache-10da4a26be5ad4da.arrow

# %%
# load the model
model = AutoModelForSequenceClassification.from_pretrained("bert-base-cased", num_labels=5)
# Out:
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.decoder.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
metric = load_metric("accuracy")

def compute_metrics(eval_pred):
    """Compute the accuracy"""
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return metric.compute(predictions=predictions, references=labels)
# Out:
# /tmp/ipykernel_24495/2030860227.py:1: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   metric = load_metric("accuracy")

# %%
from transformers import TrainingArguments

training_args = TrainingArguments("test-trainer")

# %%
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)
trainer = Trainer(
    model,
    training_args,
    train_dataset=small_train_dataset,
    eval_dataset=small_eval_dataset,
    data_collator=data_collator,
    tokenizer=tokenizer,
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [11], line 2
#       1 data_collator = DataCollatorWithPadding(tokenizer=tokenizer)
# ----> 2 trainer = Trainer(
#       3     model,
#       4     training_args,
#       5     train_dataset=small_train_dataset,
#       6     eval_dataset=small_eval_dataset,
#       7     data_collator=data_collator,
#       8     tokenizer=tokenizer,
#       9 )
#
# File ~/.local/lib/python3.10/site-packages/transformers/trainer.py:492, in Trainer.__init__(self, model, args, data_collator, train_dataset, eval_dataset, tokenizer, model_init, compute_metrics, callbacks, optimizers, preprocess_logits_for_metrics)
#     490 default_callbacks = DEFAULT_CALLBACKS + get_reporting_integration_callbacks(self.args.report_to)
#     491 callbacks = default_callbacks if callbacks is None else default_callbacks + callbacks
# --> 492 self.callback_handler = CallbackHandler(
#     493     callbacks, self.model, self.tokenizer, self.optimizer, self.lr_scheduler
#     494 )
#     495 self.add_callback(PrinterCallback if self.args.disable_tqdm else DEFAULT_PROGRESS_CALLBACK)
#     497 # Will be set to True by `self._setup_loggers()` on first call to `self.log()`.
#
# File ~/.local/lib/python3.10/site-packages/transformers/trainer_callback.py:296, in CallbackHandler.__init__(self, callbacks, model, tokenizer, optimizer, lr_scheduler)
#     294 self.callbacks = []
#     295 for cb in callbacks:
# --> 296     self.add_callback(cb)
#     297 self.model = model
#     298 self.tokenizer = tokenizer
#
# File ~/.local/lib/python3.10/site-packages/transformers/trainer_callback.py:313, in CallbackHandler.add_callback(self, callback)
#     312 def add_callback(self, callback):
# --> 313     cb = callback() if isinstance(callback, type) else callback
#     314     cb_class = callback if isinstance(callback, type) else callback.__class__
#     315     if cb_class in [c.__class__ for c in self.callbacks]:
#
# File ~/.local/lib/python3.10/site-packages/transformers/integrations.py:843, in MLflowCallback.__init__(self)
#     841 if not is_mlflow_available():
#     842     raise RuntimeError("MLflowCallback requires mlflow to be installed. Run `pip install mlflow`.")
# --> 843 import mlflow
#     845 self._MAX_PARAM_VAL_LENGTH = mlflow.utils.validation.MAX_PARAM_VAL_LENGTH
#     846 self._MAX_PARAMS_TAGS_PER_BATCH = mlflow.utils.validation.MAX_PARAMS_TAGS_PER_BATCH
#
# File ~/.local/lib/python3.10/site-packages/mlflow/__init__.py:41
#      38 warnings.filterwarnings("ignore", message="numpy.dtype size changed")
#      39 warnings.filterwarnings("ignore", message="numpy.ufunc size changed")
# ---> 41 from mlflow import projects  # pylint: disable=unused-import
#      42 from mlflow import tracking  # pylint: disable=unused-import
#      43 from mlflow import models  # pylint: disable=unused-import
#
# File ~/.local/lib/python3.10/site-packages/mlflow/projects/__init__.py:10
#       7 import logging
#       8 import warnings
# ---> 10 import mlflow.projects.databricks
#      11 from mlflow import tracking
#      12 from mlflow.entities import RunStatus
#
# File ~/.local/lib/python3.10/site-packages/mlflow/projects/databricks.py:12
#       9 import posixpath
#      10 import re
# ---> 12 from mlflow import tracking
#      13 from mlflow.entities import RunStatus
#      14 from mlflow.exceptions import MlflowException
#
# File ~/.local/lib/python3.10/site-packages/mlflow/tracking/__init__.py:8
#       1 """
#       2 The ``mlflow.tracking`` module provides a Python CRUD interface to MLflow experiments
#       3 and runs. This is a lower level API that directly translates to MLflow
#       4 `REST API <../rest-api.html>`_ calls.
#       5 For a higher level API for managing an "active run", use the :py:mod:`mlflow` module.
#       6 """
# ----> 8 from mlflow.tracking.client import MlflowClient
#       9 from mlflow.tracking._tracking_service.utils import (
#      10     set_tracking_uri,
#      11     get_tracking_uri,
#    (...)
#      14     _TRACKING_URI_ENV_VAR,
#      15 )
#      16 from mlflow.tracking._model_registry.utils import (
#      17     set_registry_uri,
#      18     get_registry_uri,
#      19 )
#
# File ~/.local/lib/python3.10/site-packages/mlflow/tracking/client.py:16
#      13 import yaml
#      14 from typing import Any, Dict, Sequence, List, Optional, Union, TYPE_CHECKING
# ---> 16 from mlflow.entities import Experiment, Run, RunInfo, Param, Metric, RunTag, FileInfo, ViewType
#      17 from mlflow.store.entities.paged_list import PagedList
#      18 from mlflow.entities.model_registry import RegisteredModel, ModelVersion
#
# File ~/.local/lib/python3.10/site-packages/mlflow/entities/__init__.py:6
#       1 """
#       2 The ``mlflow.entities`` module defines entities returned by the MLflow
#       3 `REST API <../rest-api.html>`_.
#       4 """
# ----> 6 from mlflow.entities.experiment import Experiment
#       7 from mlflow.entities.experiment_tag import ExperimentTag
#       8 from mlflow.entities.file_info import FileInfo
#
# File ~/.local/lib/python3.10/site-packages/mlflow/entities/experiment.py:2
#       1 from mlflow.entities._mlflow_object import _MLflowObject
# ----> 2 from mlflow.entities.experiment_tag import ExperimentTag
#       3 from mlflow.protos.service_pb2 import (
#       4     Experiment as ProtoExperiment,
#       5     ExperimentTag as ProtoExperimentTag,
#       6 )
#       9 class Experiment(_MLflowObject):
#
# File ~/.local/lib/python3.10/site-packages/mlflow/entities/experiment_tag.py:2
#       1 from mlflow.entities._mlflow_object import _MLflowObject
# ----> 2 from mlflow.protos.service_pb2 import ExperimentTag as ProtoExperimentTag
#       5 class ExperimentTag(_MLflowObject):
#       6     """Tag object associated with an experiment."""
#
# File ~/.local/lib/python3.10/site-packages/mlflow/protos/service_pb2.py:18
#      13 # @@protoc_insertion_point(imports)
#      15 _sym_db = _symbol_database.Default()
# ---> 18 from .scalapb import scalapb_pb2 as scalapb_dot_scalapb__pb2
#      19 from . import databricks_pb2 as databricks__pb2
#      22 DESCRIPTOR = _descriptor_pool.Default().AddSerializedFile(b'\n\rservice.proto\x12\x06mlflow\x1a\x15scalapb/scalapb.proto\x1a\x10\x64\x61tabricks.proto\"H\n\x06Metric\x12\x0b\n\x03key\x18\x01 \x01(\t\x12\r\n\x05value\x18\x02 \x01(\x01\x12\x11\n\ttimestamp\x18\x03 \x01(\x03\x12\x0f\n\x04step\x18\x04 \x01(\x03:\x01\x30\"#\n\x05Param\x12\x0b\n\x03key\x18\x01 \x01(\t\x12\r\n\x05value\x18\x02 \x01(\t\"C\n\x03Run\x12\x1d\n\x04info\x18\x01 \x01(\x0b\x32\x0f.mlflow.RunInfo\x12\x1d\n\x04\x64\x61ta\x18\x02 \x01(\x0b\x32\x0f.mlflow.RunData\"g\n\x07RunData\x12\x1f\n\x07metrics\x18\x01 \x03(\x0b\x32\x0e.mlflow.Metric\x12\x1d\n\x06params\x18\x02 \x03(\x0b\x32\r.mlflow.Param\x12\x1c\n\x04tags\x18\x03 \x03(\x0b\x32\x0e.mlflow.RunTag\"$\n\x06RunTag\x12\x0b\n\x03key\x18\x01 \x01(\t\x12\r\n\x05value\x18\x02 \x01(\t\"+\n\rExperimentTag\x12\x0b\n\x03key\x18\x01 \x01(\t\x12\r\n\x05value\x18\x02 \x01(\t\"\xcb\x01\n\x07RunInfo\x12\x0e\n\x06run_id\x18\x0f \x01(\t\x12\x10\n\x08run_uuid\x18\x01 \x01(\t\x12\x15\n\rexperiment_id\x18\x02 \x01(\t\x12\x0f\n\x07user_id\x18\x06 \x01(\t\x12!\n\x06status\x18\x07 \x01(\x0e\x32\x11.mlflow.RunStatus\x12\x12\n\nstart_time\x18\x08 \x01(\x03\x12\x10\n\x08\x65nd_time\x18\t \x01(\x03\x12\x14\n\x0c\x61rtifact_uri\x18\r \x01(\t\x12\x17\n\x0flifecycle_stage\x18\x0e \x01(\t\"\xbb\x01\n\nExperiment\x12\x15\n\rexperiment_id\x18\x01 \x01(\t\x12\x0c\n\x04name\x18\x02 \x01(\t\x12\x19\n\x11\x61rtifact_location\x18\x03 \x01(\t\x12\x17\n\x0flifecycle_stage\x18\x04 \x01(\t\x12\x18\n\x10last_update_time\x18\x05 \x01(\x03\x12\x15\n\rcreation_time\x18\x06 \x01(\x03\x12#\n\x04tags\x18\x07 \x03(\x0b\x32\x15.mlflow.ExperimentTag\"\xb6\x01\n\x10\x43reateExperiment\x12\x12\n\x04name\x18\x01 \x01(\tB\x04\xf8\x86\x19\x01\x12\x19\n\x11\x61rtifact_location\x18\x02 \x01(\t\x12#\n\x04tags\x18\x03 \x03(\x0b\x32\x15.mlflow.ExperimentTag\x1a!\n\x08Response\x12\x15\n\rexperiment_id\x18\x01 \x01(\t:+\xe2?(\n&com.databricks.rpc.RPC[$this.Response]\"\xdc\x01\n\x0fListExperiments\x12#\n\tview_type\x18\x01 \x01(\x0e\x32\x10.mlflow.ViewType\x12\x13\n\x0bmax_results\x18\x02 \x01(\x03\x12\x12\n\npage_token\x18\x03 \x01(\t\x1aL\n\x08Response\x12\'\n\x0b\x65xperiments\x18\x01 \x03(\x0b\x32\x12.mlflow.Experiment\x12\x17\n\x0fnext_page_token\x18\x02 \x01(\t:-\x18\x01\xe2?(\n&com.databricks.rpc.RPC[$this.Response]\"\xfe\x01\n\x11SearchExperiments\x12\x13\n\x0bmax_results\x18\x01 \x01(\x03\x12\x12\n\npage_token\x18\x02 \x01(\t\x12\x0e\n\x06\x66ilter\x18\x03 \x01(\t\x12\x10\n\x08order_by\x18\x04 \x03(\t\x12#\n\tview_type\x18\x05 \x01(\x0e\x32\x10.mlflow.ViewType\x1aL\n\x08Response\x12\'\n\x0b\x65xperiments\x18\x01 \x03(\x0b\x32\x12.mlflow.Experiment\x12\x17\n\x0fnext_page_token\x18\x02 \x01(\t:+\xe2?(\n&com.databricks.rpc.RPC[$this.Response]\"\xb0\x01\n\rGetExperiment\x12\x1b\n\rexperiment_id\x18\x01 \x01(\tB\x04\xf8\x86\x19\x01\x1aU\n\x08Response\x12&\n\nexperiment\x18\x01 \x01(\x0b\x32\x12.mlflow.Experiment\x12!\n\x04runs\x18\x02 \x03(\x0b\x32\x0f.mlflow.RunInfoB\x02\x18\x01:+\xe2?(\n&com.databricks.rpc.RPC[$this.Response]\"h\n\x10\x44\x65leteExperiment\x12\x1b\n\rexperiment_id\x18\x01 \x01(\tB\x04\xf8\x86\x19\x01\x1a\n\n\x08Response:+\xe2?(\n&com.databricks.rpc.RPC[$this.Response]\"i\n\x11RestoreExperiment\x12\x1b\n\rexperiment_id\x18\x01 \x01(\tB\x04\xf8\x86\x19\x01\x1a\n\n\x08Response:+\xe2?(\n&com.databricks.rpc.RPC[$this.Response]\"z\n\x10UpdateExperiment\x12\x1b\n\rexperiment_id\x18\x01 \x01(\tB\x04\xf8\x86\x19\x01\x12\x10\n\x08new_name\x18\x02 \x01(\t\x1a\n\n\x08Response:+\xe2?(\n&com.databricks.rpc.RPC[$this.Response]\"\xb8\x01\n\tCreateRun\x12\x15\n\rexperiment_id\x18\x01 \x01(\t\x12\x0f\n\x07user_id\x18\x02 \x01(\t\x12\x12\n\nstart_time\x18\x07 \x01(\x03\x12\x1c\n\x04tags\x18\t \x03(\x0b\x32\x0e.mlflow.RunTag\x1a$\n\x08Response\x12\x18\n\x03run\x18\x01 \x01(\x0b\x32\x0b.mlflow.Run:+\xe2?(\n&com.databricks.rpc.RPC[$this.Response]\"\xbe\x01\n\tUpdateRun\x12\x0e\n\x06run_id\x18\x04 \x01(\t\x12\x10\n\x08run_uuid\x18\x01 \x01(\t\x12!\n\x06status\x18\x ...
#
# File ~/.local/lib/python3.10/site-packages/mlflow/protos/scalapb/scalapb_pb2.py:22
#      18 DESCRIPTOR = _descriptor_pool.Default().AddSerializedFile(b'\n\x15scalapb/scalapb.proto\x12\x07scalapb\x1a google/protobuf/descriptor.proto\"L\n\x0eScalaPbOptions\x12\x14\n\x0cpackage_name\x18\x01 \x01(\t\x12\x14\n\x0c\x66lat_package\x18\x02 \x01(\x08\x12\x0e\n\x06import\x18\x03 \x03(\t\"!\n\x0eMessageOptions\x12\x0f\n\x07\x65xtends\x18\x01 \x03(\t\"\x1c\n\x0c\x46ieldOptions\x12\x0c\n\x04type\x18\x01 \x01(\t:G\n\x07options\x12\x1c.google.protobuf.FileOptions\x18\xfc\x07 \x01(\x0b\x32\x17.scalapb.ScalaPbOptions:J\n\x07message\x12\x1f.google.protobuf.MessageOptions\x18\xfc\x07 \x01(\x0b\x32\x17.scalapb.MessageOptions:D\n\x05\x66ield\x12\x1d.google.protobuf.FieldOptions\x18\xfc\x07 \x01(\x0b\x32\x15.scalapb.FieldOptionsB\x1e\n\x1corg.mlflow.scalapb_interface')
#      21 OPTIONS_FIELD_NUMBER = 1020
# ---> 22 options = DESCRIPTOR.extensions_by_name['options']
#      23 MESSAGE_FIELD_NUMBER = 1020
#      24 message = DESCRIPTOR.extensions_by_name['message']
#
# AttributeError: 'NoneType' object has no attribute 'extensions_by_name'
